# %% [markdown]
# ## Extracting Text from PDF and Configuring PII Redactor

# %% [markdown]
# **Author**: Pooja Holkar ,
# **email**:poholkar@in.ibm.com
#
# Click link to open notebook in google colab:  [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/IBM/data-prep-kit/blob/dev/examples/notebooks/PII/Run_your_first_PII_redactor_transform.ipynb)
#
#
# ### What is a PII Redactor?
#
# A PII (Personally Identifiable Information) Redactor is a tool designed to identify and redact sensitive information in text data. PII includes details that can be used to identify an individual, such as:
#
# Names
# Email addresses
# Phone numbers
# Addresses
# Financial details (e.g., credit card numbers)
#
# ### Overview of the use case
# In this usecase, the PII Redactor is applied to text extracted from invoices to ensure sensitive customer information is not exposed during processing, sharing, or storage.
#
#  **Workflow Overview**
#
# The text from the invoice (a PDF document in this case) is extracted using the pdfplumber library.
#
#  **Redactor Configuration**
#
# The system is configured to recognize specific PII entities relevant to invoices, such as:
# Customer names
# Email addresses
# Phone numbers
# Shipping addresses
#
#  **PII Detection and Redaction**
#
# The redactor scans the extracted text and applies redaction rules, replacing sensitive details with placeholders.
# Output:
#
# The redacted text is displayed alongside a summary of all identified PII entities for auditing purposes.
#
# ### Why is PII Redaction Important?
#
#  **Data Privacy Compliance**: Adheres to regulations like GDPR, HIPAA, or CCPA that mandate safeguarding customer information.
#
#  **Risk Mitigation**: Prevents unauthorized access to or misuse of sensitive data.
#
#  **Automation Benefits**: Simplifies and accelerates the process of securing information in large-scale document handling.

# %% [markdown]
# ### Pre-req: Install data-prep-kit dependencies

# %%
# !pip install data-prep-toolkit==0.2.2
# !pip install 'data-prep-toolkit-transforms[all]==0.2.2'
# !pip install pdfplumber 
# !pip install flair 
# !pip install spacy 
# !pip install presidio_analyzer 
# !pip install presidio_anonymizer==2.2.355
# Out:
# Requirement already satisfied: data-prep-toolkit==0.2.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (0.2.2)
# Collecting numpy<1.29.0 (from data-prep-toolkit==0.2.2)
#   Using cached numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (61 kB)
# Requirement already satisfied: pyarrow==16.1.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit==0.2.2) (16.1.0)
# Requirement already satisfied: boto3==1.34.69 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit==0.2.2) (1.34.69)
# Collecting argparse (from data-prep-toolkit==0.2.2)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: mmh3 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit==0.2.2) (4.1.0)
# Requirement already satisfied: psutil in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit==0.2.2) (6.1.0)
# Requirement already satisfied: botocore<1.35.0,>=1.34.69 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from boto3==1.34.69->data-prep-toolkit==0.2.2) (1.34.162)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from boto3==1.34.69->data-prep-toolkit==0.2.2) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from boto3==1.34.69->data-prep-toolkit==0.2.2) (0.10.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from botocore<1.35.0,>=1.34.69->boto3==1.34.69->data-prep-toolkit==0.2.2) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from botocore<1.35.0,>=1.34.69->boto3==1.34.69->data-prep-toolkit==0.2.2) (2.2.3)
# Requirement already satisfied: six>=1.5 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.69->boto3==1.34.69->data-prep-toolkit==0.2.2) (1.17.0)
# Using cached numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse, numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# blis 1.0.1 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.2 requires numpy<2.1.0,>=2.0.0; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed argparse-1.4.0 numpy-1.26.4
# Requirement already satisfied: data-prep-toolkit-transforms==0.2.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (0.2.2)
# Requirement already satisfied: data-prep-toolkit>=0.2.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms==0.2.2->data-prep-toolkit-transforms[all]==0.2.2) (0.2.2)
# Requirement already satisfied: bs4==0.0.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (0.0.2)
# Requirement already satisfied: transformers==4.38.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (4.38.2)
# Requirement already satisfied: parameterized in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (0.9.0)
# Requirement already satisfied: pandas in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (2.2.2)
# Requirement already satisfied: docling-core==2.3.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (2.3.0)
# Requirement already satisfied: pydantic<2.10.0,>=2.0.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (2.9.2)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.22 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (0.11.23)
# Requirement already satisfied: fasttext==0.9.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (0.9.2)
# Requirement already satisfied: langcodes==3.3.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (3.3.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.21.4 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (0.26.3)
# Requirement already satisfied: numpy==1.26.4 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (1.26.4)
# Requirement already satisfied: sentence-transformers==3.0.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (3.0.1)
# Requirement already satisfied: docling-ibm-models==2.0.3 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (2.0.3)
# Requirement already satisfied: deepsearch-glm==0.26.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (0.26.1)
# Requirement already satisfied: docling==2.3.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (2.3.1)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (1.2.0)
# Requirement already satisfied: nltk==3.9.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (3.9.1)
# Requirement already satisfied: torch<=2.4.1,>=2.2.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (2.4.1)
# Requirement already satisfied: mmh3>=4.1.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (4.1.0)
# Requirement already satisfied: xxhash==3.4.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (3.4.1)
# Requirement already satisfied: duckdb>=0.10.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (1.1.3)
# Requirement already satisfied: data_prep_connector>=0.2.3 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit-transforms[all]==0.2.2) (0.2.3)
# Requirement already satisfied: beautifulsoup4 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from bs4==0.0.2->data-prep-toolkit-transforms[all]==0.2.2) (4.12.3)
# Requirement already satisfied: pyarrow==16.1.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit>=0.2.2->data-prep-toolkit-transforms==0.2.2->data-prep-toolkit-transforms[all]==0.2.2) (16.1.0)
# Requirement already satisfied: boto3==1.34.69 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit>=0.2.2->data-prep-toolkit-transforms==0.2.2->data-prep-toolkit-transforms[all]==0.2.2) (1.34.69)
# Collecting argparse (from data-prep-toolkit>=0.2.2->data-prep-toolkit-transforms==0.2.2->data-prep-toolkit-transforms[all]==0.2.2)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: psutil in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data-prep-toolkit>=0.2.2->data-prep-toolkit-transforms==0.2.2->data-prep-toolkit-transforms[all]==0.2.2) (6.1.0)
# Requirement already satisfied: docutils!=0.21 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from deepsearch-glm==0.26.1->data-prep-toolkit-transforms[all]==0.2.2) (0.21.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from deepsearch-glm==0.26.1->data-prep-toolkit-transforms[all]==0.2.2) (1.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from deepsearch-glm==0.26.1->data-prep-toolkit-transforms[all]==0.2.2) (2.32.3)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from deepsearch-glm==0.26.1->data-prep-toolkit-transforms[all]==0.2.2) (13.9.4)
# Requirement already satisfied: tabulate>=0.8.9 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from deepsearch-glm==0.26.1->data-prep-toolkit-transforms[all]==0.2.2) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from deepsearch-glm==0.26.1->data-prep-toolkit-transforms[all]==0.2.2) (4.67.1)
# Requirement already satisfied: certifi>=2024.7.4 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (2024.8.30)
# Requirement already satisfied: docling-parse<3.0.0,>=2.0.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (2.1.2)
# Requirement already satisfied: easyocr<2.0,>=1.7 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (1.7.2)
# Requirement already satisfied: marko<3.0.0,>=2.1.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (2.1.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.3.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (2.6.1)
# Requirement already satisfied: pypdfium2<5.0.0,>=4.30.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (4.30.0)
# Requirement already satisfied: python-docx<2.0.0,>=1.1.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (1.1.2)
# Requirement already satisfied: python-pptx<2.0.0,>=1.0.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (1.0.2)
# Requirement already satisfied: rtree<2.0.0,>=1.3.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (1.3.0)
# Requirement already satisfied: scipy<2.0.0,>=1.14.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (1.14.1)
# Requirement already satisfied: typer<0.13.0,>=0.12.5 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (0.12.5)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling-core==2.3.0->data-prep-toolkit-transforms[all]==0.2.2) (1.1.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling-core==2.3.0->data-prep-toolkit-transforms[all]==0.2.2) (4.23.0)
# Requirement already satisfied: pillow<11.0.0,>=10.3.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling-core==2.3.0->data-prep-toolkit-transforms[all]==0.2.2) (10.4.0)
# Requirement already satisfied: jsonlines<4.0.0,>=3.1.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling-ibm-models==2.0.3->data-prep-toolkit-transforms[all]==0.2.2) (3.1.0)
# Requirement already satisfied: lxml<5.0.0,>=4.9.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling-ibm-models==2.0.3->data-prep-toolkit-transforms[all]==0.2.2) (4.9.4)
# Requirement already satisfied: mean_average_precision<2022.0.0.0,>=2021.4.26.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling-ibm-models==2.0.3->data-prep-toolkit-transforms[all]==0.2.2) (2021.4.26.0)
# Requirement already satisfied: opencv-python-headless<5.0.0.0,>=4.6.0.66 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling-ibm-models==2.0.3->data-prep-toolkit-transforms[all]==0.2.2) (4.10.0.84)
# Requirement already satisfied: torchvision<1,>=0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from docling-ibm-models==2.0.3->data-prep-toolkit-transforms[all]==0.2.2) (0.19.1)
# Requirement already satisfied: pybind11>=2.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from fasttext==0.9.2->data-prep-toolkit-transforms[all]==0.2.2) (2.13.6)
# Requirement already satisfied: setuptools>=0.7.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from fasttext==0.9.2->data-prep-toolkit-transforms[all]==0.2.2) (65.5.0)
# Requirement already satisfied: click in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from nltk==3.9.1->data-prep-toolkit-transforms[all]==0.2.2) (8.1.7)
# Requirement already satisfied: joblib in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from nltk==3.9.1->data-prep-toolkit-transforms[all]==0.2.2) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from nltk==3.9.1->data-prep-toolkit-transforms[all]==0.2.2) (2024.11.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from pandas->data-prep-toolkit-transforms[all]==0.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from pandas->data-prep-toolkit-transforms[all]==0.2.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from pandas->data-prep-toolkit-transforms[all]==0.2.2) (2024.2)
# Requirement already satisfied: scikit-learn in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from sentence-transformers==3.0.1->data-prep-toolkit-transforms[all]==0.2.2) (1.5.2)
# Requirement already satisfied: filelock in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from transformers==4.38.2->data-prep-toolkit-transforms[all]==0.2.2) (3.16.1)
# Requirement already satisfied: packaging>=20.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from transformers==4.38.2->data-prep-toolkit-transforms[all]==0.2.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from transformers==4.38.2->data-prep-toolkit-transforms[all]==0.2.2) (6.0.2)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from transformers==4.38.2->data-prep-toolkit-transforms[all]==0.2.2) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from transformers==4.38.2->data-prep-toolkit-transforms[all]==0.2.2) (0.4.5)
# Requirement already satisfied: botocore<1.35.0,>=1.34.69 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from boto3==1.34.69->data-prep-toolkit>=0.2.2->data-prep-toolkit-transforms==0.2.2->data-prep-toolkit-transforms[all]==0.2.2) (1.34.162)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from boto3==1.34.69->data-prep-toolkit>=0.2.2->data-prep-toolkit-transforms==0.2.2->data-prep-toolkit-transforms[all]==0.2.2) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from boto3==1.34.69->data-prep-toolkit>=0.2.2->data-prep-toolkit-transforms==0.2.2->data-prep-toolkit-transforms[all]==0.2.2) (0.10.4)
# Requirement already satisfied: scrapy>=2.11.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (2.12.0)
# Requirement already satisfied: tldextract>=5.1.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (5.1.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.21.4->data-prep-toolkit-transforms[all]==0.2.2) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.21.4->data-prep-toolkit-transforms[all]==0.2.2) (4.12.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (3.11.10)
# Requirement already satisfied: dataclasses-json in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (1.0.8)
# Requirement already satisfied: httpx in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (0.28.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (3.4.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (0.8.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (0.9.0)
# Requirement already satisfied: wrapt in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (1.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from pydantic<2.10.0,>=2.0.0->data-prep-toolkit-transforms[all]==0.2.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from pydantic<2.10.0,>=2.0.0->data-prep-toolkit-transforms[all]==0.2.2) (2.23.4)
# Requirement already satisfied: sympy in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from torch<=2.4.1,>=2.2.2->data-prep-toolkit-transforms[all]==0.2.2) (1.13.1)
# Requirement already satisfied: jinja2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from torch<=2.4.1,>=2.2.2->data-prep-toolkit-transforms[all]==0.2.2) (3.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (1.18.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from beautifulsoup4->bs4==0.0.2->data-prep-toolkit-transforms[all]==0.2.2) (2.6)
# Requirement already satisfied: scikit-image in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from easyocr<2.0,>=1.7->docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (0.24.0)
# Requirement already satisfied: python-bidi in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from easyocr<2.0,>=1.7->docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (0.6.3)
# Requirement already satisfied: Shapely in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from easyocr<2.0,>=1.7->docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (2.0.6)
# Requirement already satisfied: pyclipper in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from easyocr<2.0,>=1.7->docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (1.3.0.post6)
# Requirement already satisfied: ninja in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from easyocr<2.0,>=1.7->docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (1.11.1.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core==2.3.0->data-prep-toolkit-transforms[all]==0.2.2) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core==2.3.0->data-prep-toolkit-transforms[all]==0.2.2) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.16.0->docling-core==2.3.0->data-prep-toolkit-transforms[all]==0.2.2) (0.22.3)
# Requirement already satisfied: six>=1.5 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->data-prep-toolkit-transforms[all]==0.2.2) (1.17.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from python-pptx<2.0.0,>=1.0.2->docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.3->deepsearch-glm==0.26.1->data-prep-toolkit-transforms[all]==0.2.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.3->deepsearch-glm==0.26.1->data-prep-toolkit-transforms[all]==0.2.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.32.3->deepsearch-glm==0.26.1->data-prep-toolkit-transforms[all]==0.2.2) (2.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from rich<14.0.0,>=13.7.0->deepsearch-glm==0.26.1->data-prep-toolkit-transforms[all]==0.2.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from rich<14.0.0,>=13.7.0->deepsearch-glm==0.26.1->data-prep-toolkit-transforms[all]==0.2.2) (2.18.0)
# Requirement already satisfied: Twisted>=21.7.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (24.11.0)
# Requirement already satisfied: cryptography>=37.0.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (44.0.0)
# Requirement already satisfied: cssselect>=0.9.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (1.3.2)
# Requirement already satisfied: parsel>=1.5.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (1.9.1)
# Requirement already satisfied: pyOpenSSL>=22.0.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (24.3.0)
# Requirement already satisfied: queuelib>=1.4.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (1.7.0)
# Requirement already satisfied: service-identity>=18.1.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (24.2.0)
# Requirement already satisfied: w3lib>=1.17.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (2.2.1)
# Requirement already satisfied: zope.interface>=5.1.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (7.2)
# Requirement already satisfied: protego>=0.1.15 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (0.3.1)
# Requirement already satisfied: itemadapter>=0.1.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (0.10.0)
# Requirement already satisfied: defusedxml>=0.7.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (0.7.1)
# Requirement already satisfied: PyDispatcher>=2.0.5 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (3.1.1)
# Requirement already satisfied: requests-file>=1.4 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from tldextract>=5.1.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (2.1.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from typer<0.13.0,>=0.12.5->docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (3.23.1)
# Requirement already satisfied: anyio in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (4.6.2.post1)
# Requirement already satisfied: httpcore==1.* in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from jinja2->torch<=2.4.1,>=2.2.2->data-prep-toolkit-transforms[all]==0.2.2) (3.0.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scikit-learn->sentence-transformers==3.0.1->data-prep-toolkit-transforms[all]==0.2.2) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from sympy->torch<=2.4.1,>=2.2.2->data-prep-toolkit-transforms[all]==0.2.2) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from cryptography>=37.0.0->scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (1.17.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->deepsearch-glm==0.26.1->data-prep-toolkit-transforms[all]==0.2.2) (0.1.2)
# Requirement already satisfied: pyasn1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from service-identity>=18.1.0->scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (0.6.1)
# Requirement already satisfied: pyasn1-modules in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from service-identity>=18.1.0->scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (0.4.1)
# Requirement already satisfied: automat>=24.8.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from Twisted>=21.7.0->scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (24.8.1)
# Requirement already satisfied: constantly>=15.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from Twisted>=21.7.0->scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from Twisted>=21.7.0->scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from Twisted>=21.7.0->scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (24.7.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]==0.2.2) (1.2.2)
# Requirement already satisfied: imageio>=2.33 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from scikit-image->easyocr<2.0,>=1.7->docling==2.3.1->data-prep-toolkit-transforms[all]==0.2.2) (0.4)
# Requirement already satisfied: pycparser in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=37.0.0->scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (2.22)
# Requirement already satisfied: tomli in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from incremental>=24.7.0->Twisted>=21.7.0->scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]==0.2.2) (2.2.1)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0
# Requirement already satisfied: pdfplumber in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (0.11.4)
# ...
# Requirement already satisfied: wrapt in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Using cached numpy-2.0.2-cp310-cp310-macosx_14_0_arm64.whl (5.3 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# data-prep-toolkit 0.2.2 requires numpy<1.29.0, but you have numpy 2.0.2 which is incompatible.
# deepsearch-glm 0.26.1 requires numpy<2.0.0,>=1.26.4; python_version >= "3.9" and python_version < "3.13", but you have numpy 2.0.2 which is incompatible.
# docling-ibm-models 2.0.3 requires numpy<2.0.0,>=1.24.4; python_version < "3.13", but you have numpy 2.0.2 which is incompatible.
# llama-index-core 0.11.23 requires numpy<2.0.0, but you have numpy 2.0.2 which is incompatible.
# transformer-smaller-training-vocab 0.4.0 requires numpy<2.0.0,>=1.21.0; python_version >= "3.9", but you have numpy 2.0.2 which is incompatible.
# Successfully installed numpy-2.0.2
# Requirement already satisfied: presidio_analyzer in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (2.2.355)
# Requirement already satisfied: phonenumbers<9.0.0,>=8.12 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from presidio_analyzer) (8.13.51)
# Requirement already satisfied: pyyaml in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from presidio_analyzer) (6.0.2)
# Requirement already satisfied: regex in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from presidio_analyzer) (2024.11.6)
# Requirement already satisfied: spacy<4.0.0,>=3.4.4 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from presidio_analyzer) (3.8.2)
# Requirement already satisfied: tldextract in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from presidio_analyzer) (5.1.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (8.3.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.9.2)
# Requirement already satisfied: jinja2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (3.1.4)
# Requirement already satisfied: setuptools in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.0.2)
# Requirement already satisfied: idna in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from tldextract->presidio_analyzer) (3.10)
# Requirement already satisfied: requests-file>=1.4 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from tldextract->presidio_analyzer) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from tldextract->presidio_analyzer) (3.16.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.4.4->presidio_analyzer) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.4.4->presidio_analyzer) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (2024.8.30)
# Requirement already satisfied: blis<1.1.0,>=1.0.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (1.0.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from thinc<8.4.0,>=8.3.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from jinja2->spacy<4.0.0,>=3.4.4->presidio_analyzer) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.18.0)
# Requirement already satisfied: wrapt in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (0.1.2)
# Requirement already satisfied: presidio_anonymizer==2.2.355 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (2.2.355)
# Requirement already satisfied: azure-core in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from presidio_anonymizer==2.2.355) (1.32.0)
# Requirement already satisfied: pycryptodome>=3.10.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from presidio_anonymizer==2.2.355) (3.21.0)
# Requirement already satisfied: requests>=2.21.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from azure-core->presidio_anonymizer==2.2.355) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from azure-core->presidio_anonymizer==2.2.355) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from azure-core->presidio_anonymizer==2.2.355) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from requests>=2.21.0->azure-core->presidio_anonymizer==2.2.355) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from requests>=2.21.0->azure-core->presidio_anonymizer==2.2.355) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from requests>=2.21.0->azure-core->presidio_anonymizer==2.2.355) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/poojaholkar/GSI/WATSONX/WATSONXDATA/DPK/GITHUBCOPY/poojagit/transforms/language/pii_redactor/python/venv/lib/python3.10/site-packages (from requests>=2.21.0->azure-core->presidio_anonymizer==2.2.355) (2024.8.30)

# %%
import pdfplumber
from pii_redactor_transform import PIIRedactorTransform

# %% [markdown]
# ### Step 1: Inspect the Data
#
# We will use simple invoice PDF
#
# [invoicedata](https://raw.githubusercontent.com/PoojaHolkar/data-prep-kit/refs/heads/dev/examples/notebooks/PII/invoicedata/Invoice.pdf)

# %%
# !wget 'https://raw.githubusercontent.com/PoojaHolkar/data-prep-kit/refs/heads/dev/examples/notebooks/PII/invoicedata/Invoice.pdf'
# Out:
# --2024-12-06 19:24:29--  https://raw.githubusercontent.com/PoojaHolkar/data-prep-kit/refs/heads/dev/examples/notebooks/PII/invoicedata/Invoice.pdf
# 185.199.109.133, 185.199.108.133, 185.199.111.133, ...tent.com)...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33150 (32K) [application/octet-stream]
# Saving to: ‘Invoice.pdf.1’
#
# Invoice.pdf.1       100%[===================>]  32.37K  --.-KB/s    in 0.04s
#
# 2024-12-06 19:24:30 (744 KB/s) - ‘Invoice.pdf.1’ saved [33150/33150]

# %%
pdf_path="Invoice.pdf"

# %% [markdown]
# ### Step 2: Extract Text from PDF
#
# This step uses the pdfplumber library to open and read a PDF file. The code processes each page of the PDF to extract text and concatenates it into a single string.

# %%
with pdfplumber.open(pdf_path) as pdf:
    text = "\n".join(page.extract_text() for page in pdf.pages)

# %% [markdown]
# ### Step 3: Configure the PII Redactor

# %% [markdown]
# This configuration defines the parameters for identifying and redacting Personally Identifiable Information (PII) in the extracted text.

# %%
config = {
    "entities": ["PERSON", "EMAIL_ADDRESS", "PHONE_NUMBER", "LOCATION"],
    "operator": "replace",
    "transformed_contents": "redacted_contents",
    "score_threshold": 0.6
}

# %% [markdown]
# ### Step 4: Initialize and Run the PII Redactor

# %% [markdown]
# This step initializes the PII Redactor using the previously defined configuration and prepares it for processing the extracted text.

# %%
redactor = PIIRedactorTransform(config)
# Out:
# 19:24:30 INFO - Loading model from flair/ner-english-large

# %% [markdown]
# ### Step 5: Apply the Redactor to Text Data

# %% [markdown]
# This step applies the initialized PII redactor to the extracted text, redacting sensitive information and providing details about the identified entities.

# %%
redacted_text, detected_entities = redactor._redact_pii(text)

# %% [markdown]
# ### Step 6: Display the Redaction Results

# %% [markdown]
# This step outputs the results of the redaction process, including the redacted text and the details of the detected PII entities.

# %%
# Step 5: Print the Results
print("Redacted Text:\n", redacted_text)
print("Detected Entities:\n", detected_entities)

# %% [markdown]
# <br>
# <br>
#
# ### This notebook effectively demonstrates how to seamlessly apply redaction for PII entities
